# %%
import pandas as pd
import numpy as np
import networkx as nx

# %%
# %%time

status = pd.read_csv('../dat/status_clean.csv')
trip   = pd.read_csv('../dat/trip_clean.csv')

# %%
print(status.shape)
print(trip.shape)
# Out:
# (71984434, 8)
# (669959, 7)

# %%
status.head()
# Out:
#    station_id  bikes_available                 time  \
# 0           2                2  2013-08-29 12:06:01
# 1           2                2  2013-08-29 12:07:01
# 2           2                2  2013-08-29 12:08:01
# 3           2                2  2013-08-29 12:09:01
# 4           2                2  2013-08-29 12:10:01
#
#                                 name        lat        long  dock_count  \
# 0  San Jose Diridon Caltrain Station  37.329732 -121.901782          27
# 1  San Jose Diridon Caltrain Station  37.329732 -121.901782          27
# 2  San Jose Diridon Caltrain Station  37.329732 -121.901782          27
# 3  San Jose Diridon Caltrain Station  37.329732 -121.901782          27
# 4  San Jose Diridon Caltrain Station  37.329732 -121.901782          27
#
#   installation_date
# 0        2013-08-06
# 1        2013-08-06
# 2        2013-08-06
# 3        2013-08-06
# 4        2013-08-06

# %%
trip.head()
# Out:
#    duration           start_date  start_station_id             end_date  \
# 0        63  2013-08-29 14:13:00                66  2013-08-29 14:14:00
# 1        70  2013-08-29 14:42:00                10  2013-08-29 14:43:00
# 2        71  2013-08-29 10:16:00                27  2013-08-29 10:17:00
# 3        77  2013-08-29 11:29:00                10  2013-08-29 11:30:00
# 4        83  2013-08-29 12:02:00                66  2013-08-29 12:04:00
#
#    end_station_id  bike_id subscription_type
# 0              66      520        Subscriber
# 1              10      661        Subscriber
# 2              27       48        Subscriber
# 3              10       26        Subscriber
# 4              67      319        Subscriber

# %%
trip[trip['start_station_id'] == 2].iloc[0]
# Out:
# duration                             454
# start_date           2013-08-29 19:18:00
# start_station_id                       2
# end_date             2013-08-29 19:25:00
# end_station_id                         7
# bike_id                               91
# subscription_type             Subscriber
# Name: 213, dtype: object

# %%
status[(status['station_id'] == 2) & (status['time'] == '2013-08-29 19:25:00')]
# Out:
# Empty DataFrame
# Columns: [station_id, bikes_available, time, name, lat, long, dock_count, installation_date]
# Index: []

# %%
status[status['time'] == '2013-08-29 19:18:00']
# Out:
# Empty DataFrame
# Columns: [station_id, bikes_available, time, name, lat, long, dock_count, installation_date]
# Index: []

# %%
status[status['station_id']==2].iloc[380:400]
# Out:
#      station_id  bikes_available                 time  \
# 380           2                3  2013-08-29 19:06:01
# 381           2                3  2013-08-29 19:07:03
# 382           2                3  2013-08-29 19:08:01
# 383           2                3  2013-08-29 19:10:01
# 384           2                3  2013-08-29 19:11:02
# 385           2                3  2013-08-29 19:12:01
# 386           2                3  2013-08-29 19:13:02
# 387           2                3  2013-08-29 19:15:01
# 388           2                3  2013-08-29 19:16:01
# 389           2                3  2013-08-29 19:17:03
# 390           2                3  2013-08-29 19:18:01
# 391           2                2  2013-08-29 19:19:01
# 392           2                2  2013-08-29 19:20:01
# 393           2                2  2013-08-29 19:21:02
# 394           2                2  2013-08-29 19:22:01
# 395           2                2  2013-08-29 19:23:01
# ...
